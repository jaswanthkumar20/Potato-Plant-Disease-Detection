# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-295-gac6c4383 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 29.0/78.2 GB disk)

# %%
#Training the model
# !python train.py --img 640 --batch 32 --epochs 500 --data /content/drive/MyDrive/yolov5/data/custom.yaml --weights yolov5s.pt --cache
# Out:
# 2024-04-05 09:53:25.954406: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-05 09:53:25.954454: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-05 09:53:25.955887: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
#Testing the model
# !python detect.py --weights /content/drive/MyDrive/yolov5/runs/train/exp3/weights/best.pt --img 640 --conf 0.2 --source /content/drive/MyDrive/Dataset/Test/images
# Out:
# [Errno 2] No such file or directory: '/content/yolov5/'
# /content/drive/MyDrive/yolov5
# detect: weights=['/content/drive/MyDrive/yolov5/runs/train/exp3/weights/best.pt'], source=/content/drive/MyDrive/Dataset/Test/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.2, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-295-gac6c4383 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/60 /content/drive/MyDrive/Dataset/Test/images/image1501.jpg: 640x640 2 Stresseds, 3 Healthys, 11.5ms
# ...

# %%
import cv2
from google.colab.patches import cv2_imshow
#F1 curve
image = cv2.imread("/content/drive/MyDrive/results/F1_curve.png")
resized_image = cv2.resize(image, (700, 500))
cv2_imshow(resized_image)
# Out:
# <PIL.Image.Image image mode=RGB size=700x500>

# %%
#Precision curve

image = cv2.imread("/content/drive/MyDrive/results/P_curve.png")
resized_image = cv2.resize(image, (700, 500))
cv2_imshow(resized_image)
# Out:
# <PIL.Image.Image image mode=RGB size=700x500>

# %%
#Recall curve

image = cv2.imread("/content/drive/MyDrive/results/R_curve.png")
resized_image = cv2.resize(image, (700, 500))
cv2_imshow(resized_image)
# Out:
# <PIL.Image.Image image mode=RGB size=700x500>

# %%
#PR curve

image = cv2.imread("/content/drive/MyDrive/results/PR_curve (1).png")
resized_image = cv2.resize(image, (700, 500))
cv2_imshow(resized_image)
# Out:
# <PIL.Image.Image image mode=RGB size=700x500>

# %%
#Confusion matrix

image = cv2.imread("/content/drive/MyDrive/results/confusion_matrix.png")
resized_image = cv2.resize(image, (1000, 700))
cv2_imshow(resized_image)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x700>

# %%
#Results

image = cv2.imread("/content/drive/MyDrive/results/results.png")
resized_image = cv2.resize(image, (800, 500))
cv2_imshow(resized_image)
# Out:
# <PIL.Image.Image image mode=RGB size=800x500>

# %%
#Test sample image

image = cv2.imread("/content/drive/MyDrive/yolov5/runs/detect/exp/image1501.jpg")
resized_image = cv2.resize(image, (500, 400))
cv2_imshow(resized_image)
# Out:
# <PIL.Image.Image image mode=RGB size=500x400>
